# %% [markdown]
# <a href="https://colab.research.google.com/github/hmahmoudalkhatib-eng/mit-python-journal/blob/main/day11_mit_journal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
even_num=0

for i in range(2,12,2):
 if i% 2== 0 :
  even_num+=1
print(even_num)
# Out:
# 5

# %%
an_letters = "aefhilmnorsxAEFHILMNORSX"
word=input("i will cheer for you !, give me a word !")
times=int(input("Excitement Level? 1-10 : "))
for z in word:
  if z in an_letters:
    print("Give me an",z,":",z,)
  else:

     print("Give me a ",z, ":",z,)


print("NOW WHAT DOES THAT SPELL????")

for z in range(times):


    print(word,"!!!")
# Out:
# i will cheer for you !, give me a word !APPLE
# Excitement Level? 1-10 : 10
# Give me an A : A
# Give me a  P : P
# Give me a  P : P
# Give me an L : L
# Give me an E : E
# NOW WHAT DOES THAT SPELL????
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
# APPLE !!!
