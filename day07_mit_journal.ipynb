# %% [markdown]
# <a href="https://colab.research.google.com/github/hmahmoudalkhatib-eng/mit-python-journal/blob/main/day07_mit_journal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
starting_salary = int(input("Enter starting salary: "))
semi_annual_raise = 0.07
investment_return = 0.04
down_payment = 250000
monthly_depoist=starting_salary/12
months_count=0
low = 0
high = 10000
steps = 0
guess=0
current_savings = 0
while abs(current_savings - down_payment) >= 100:
 for months_count in range(37)
 current_savings*investment_return/12
 current_savings+=monthly_depoist
current_savings+=current_savings*investment_return/12
months_count+=1
if months_count%6==0:
 starting_salary=starting_salary*(1+semi_annual_raise)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1520/3435006813.py in <cell line: 0>()
# ----> 1 starting_salary = int(input("Enter starting salary: "))
#       2 semi_annual_raise = 0.07
#       3 investment_return = 0.04
#       4 down_payment = 250000
#       5
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
