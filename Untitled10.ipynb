# %% [markdown]
# <a href="https://colab.research.google.com/github/hmahmoudalkhatib-eng/mit-python-journal/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ask = int(input("what is your annual salary :"))
ask1 = int(input("what is your portion saved :"))
ask2 = int(input("what is the total cost of your dream home :"))
while True:


  r=0.04

  n= ask1 * r / 12
  n += ask1
  if n not == ask2:
   n+=ask1
  print(n)
  if n == ask2:
   break
# Out:
#   File "/tmp/ipykernel_671/3687318612.py", line 11
#     if n not == ask2:
#              ^
# SyntaxError: invalid syntax
