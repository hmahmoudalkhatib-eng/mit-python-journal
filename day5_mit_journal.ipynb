# %% [markdown]
# <a href="https://colab.research.google.com/github/hmahmoudalkhatib-eng/mit-python-journal/blob/main/day5_mit_journal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
annual_salary = int(input("what is your annual salary :"))
portion_saved = int(input("what is your portion saved :"))
dream_home = int(input("what is the total cost of your dream home :"))
semi_annual_raise = float(input("what is the semi annual raise :"))
current_savings = 0
down_payment = 0
r = 0.04

months_passed = 0

while current_savings < dream_home:


    formula = current_savings * r / 12

    down_payment = formula + portion_saved

    current_savings += down_payment
    months_passed += 1

print(months_passed)
# Out:
# what is your annual salary :1200
# what is your portion saved :120
# what is the total cost of your dream home :12000
# what is the semi annual raise :0.03
# 87

# %%
annual_salary=int(input("what is youur annual salary?"))
portion_saved =int(input("what is your portion saved?"))
dream_home =int(input("what is your dream home cost?"))
current_savings=0
r=0.04
months_passed =0
down_payment=0
while current_savings < dream_home:
  equation = portion_saved*r/12
  current_savings+=portion_saved
  portion_saved+=equation
  months_passed+=1
print(months_passed)
# Out:
# what is youur annual salary?1200
# what is your portion saved?120
# what is your dream home cost?12000
# 87
