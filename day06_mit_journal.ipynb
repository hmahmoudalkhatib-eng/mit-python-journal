# %% [markdown]
# <a href="https://colab.research.google.com/github/hmahmoudalkhatib-eng/mit-python-journal/blob/main/day06_mit_journal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
starting_salary = int(input("Enter starting salary: "))
semi_annual_raise = 0.07
investment_return = 0.04
down_payment = 250000

low = 0
high = 10000
steps = 0
current_savings = 0
# Out:
# Enter starting salary: 80000
# Best savings rate: 0.8271
# Steps in bisection search: 10
