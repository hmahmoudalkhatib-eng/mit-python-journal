# %% [markdown]
# <a href="https://colab.research.google.com/github/hmahmoudalkhatib-eng/mit-python-journal/blob/main/day05_mit_journal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 	annual_salary=int(input("what is youur annual salary?"))
 	dream_home =int(input("what is your dream home cost?"))
 	semi_annual_raise=float(input("what is your semi annal raise?"))

 	current_savings=0
 	months_passed=0
 	r=0.04
 	months_passed =0
 	down_payment=0
 	portion_saved=0.1*annual_salary
 	while current_savings < dream_home:
 	  equation = portion_saved*r/12
 	  current_savings+=portion_saved
 	  months_passed+=1
 	  portion_saved+=equation
 	  if months_passed %6==0:
 	     annual_salary=annual_salary*(1+semi_annual_raise)
 	     portion_saved=0.1*annual_salary
print(months_passed)
# Out:
# what is youur annual salary?1200
# what is your dream home cost?12000
# what is your semi annal raise?0.04
# 78
